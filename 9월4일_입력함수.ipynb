# %% [markdown]
# <a href="https://colab.research.google.com/github/rlarkdalsz/10820/blob/main/9%EC%9B%944%EC%9D%BC_%EC%9E%85%EB%A0%A5%ED%95%A8%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = input('이름:')
b = input('나이:')
print(a, '님 안녕하세요')
print(0-int(b), '년 후면 2020살이시네요!')

# %%
sec = int(input('시간을 초 단위로 입력하세요: '))
minutes = sec // 60
seconds = sec % 60
print(f'(minutes)분 (seconds)초')

# %%
name = inout("이름: ")
student_id = input("학번: ")
club = input("소속: ")
print("###############################")
print(" [한양과학기술고등학교 학생증 ] Wn")print(f" *학번: (student_id]")
print(f" * 성명: (name?")
print(f" * 소속: (clublwn")
print("위 사람은 본 학교의 학생임을 증명함.")
